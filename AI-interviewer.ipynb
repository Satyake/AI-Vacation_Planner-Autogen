# %%
# %%writefile AI_interview.py

from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.teams import RoundRobinGroupChat
from dotenv import load_dotenv
from autogen_agentchat.ui import Console
import os 
from autogen_agentchat.conditions import TextMentionTermination

load_dotenv()
os.environ['OPENAI_API_KEY']=os.getenv('OPENAI_API_KEY')
model_client=OpenAIChatCompletionClient(model="gpt-4o")
job_position="software engineer"
#Interviewer
interviewer=AssistantAgent(
    name="interviewer",
    model_client=model_client,
    system_message=f"""
    You are a professional interviewer for a{job_position}.

    Ask one clear question at a time and wait for the user to respond.
    Ask 3 questions in total covering technical skills and experience.
    Dont pay attention to Career coach responses, Make sure to ask questions based on candidates expertise.
    After asking 3 questions, say, 'TERMINATE' at the end of the interview.
    """
)

#Interviewee Agent # userproxyagent #user feedback
interviewee=UserProxyAgent(
    name="Interviewee",
    description="for input ",
    input_func=input,
)

#career coach
career_coach=AssistantAgent(
    name="careercoach",
    model_client=model_client,
    system_message=f"""
   you are a career coach specialized in preparing candidates for {job_position} interviews,
   after the interview provide summarized feedback under 100 words"""
)

team=RoundRobinGroupChat(
    [interviewer,interviewee,career_coach],
    max_turns=20,
    termination_condition=TextMentionTermination(text="TERMINATE")
)


async def main():
    await Console(team.run_stream(task="Conduct an interview for a software engineering position"))
#running the agent team
import asyncio
if __name__=="__main__":

    asyncio.run(main())
# Out:
# Overwriting AI_interview.py

# %%
# %%writefile .env
# OPENAI_API_KEY="sk-JFMnCjkrE-2x9-g_SUEgTKmHzy_X8JInuQlgcUiQMbT3BlbkFJ-Juw0gbRqKA1M-vg1QeEy_j9zPcAjbvAuj8XOFkaoA"
# Out:
# Writing .env

# %%
# !python -m pip install autogen-agentchat autogen-core autogen-ext tiktoken openai pydantic dotenv
# Out:
# Requirement already satisfied: autogen-agentchat in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.4.9.3)
# Requirement already satisfied: autogen-core in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.4.9.3)
# Requirement already satisfied: autogen-ext in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.4.9.3)
# Requirement already satisfied: tiktoken in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.12.0)
# Requirement already satisfied: openai in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.14.0)
# Requirement already satisfied: pydantic in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.12.5)
# Requirement already satisfied: dotenv in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.9.9)
# Requirement already satisfied: jsonref~=1.1.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from autogen-core) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from autogen-core) (1.39.1)
# Requirement already satisfied: pillow>=11.0.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from autogen-core) (12.0.0)
# Requirement already satisfied: protobuf~=5.29.3 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from autogen-core) (5.29.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from autogen-core) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: python-dotenv in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dotenv) (1.2.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from opentelemetry-api>=1.27.0->autogen-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->autogen-core) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\satya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.26.0->tiktoken) (2.6.2)
# Requirement already satisfied: colorama in c:\users\satya\appdata\roaming\python\python314\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# %%writefile requirements.txt
# autogen-agentchat
# autogen-core
# autogen-ext
# tiktoken
# openai
# pydantic
# dotenv
# Out:
# Overwriting requirements.txt
